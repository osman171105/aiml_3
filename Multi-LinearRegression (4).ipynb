# %% [markdown]
# ## Assumptions in Multi_Linear Regression
# * Linearity: The relationship between the predictors and the response is linear.
# * Independence: Observations are independent of each other.
# * Homoscedasticity: The residuals (differences between observed and predicted values) exhibit constant variance at all levels of the predicto
# * Normal Distribution of Errors: The residual of the model are normally distrubuted.
# * No mutlicollinearity: The independent variables should not be too hightly correlated with each other.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import influence_plot
import numpy as np

# %%
cars = pd.read_csv("Cars.csv")
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars = pd.DataFrame(cars, columns=["HP", "VOL","SP", "WT", "MPG"])
cars.head()
# Out:
#    HP  VOL          SP         WT        MPG
# 0  49   89  104.185353  28.762059  53.700681
# 1  55   92  105.461264  30.466833  50.013401
# 2  55   92  105.461264  30.193597  50.013401
# 3  70   92  113.461264  30.632114  45.696322
# 4  53   92  104.461264  29.889149  50.504232

# %% [markdown]
# ### DESCRIPTION OF COLUMNS
# * MPG - Milege of the car (mile per gallon)
# * VOL - Volume of the car (size)
# * SP - Top speed of the car (Miles per Hour)
# * WT - Weight of the car (pounds)
# * HP - Horse Power of the car

# %% [markdown]
# ## EDA

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   VOL     81 non-null     int64
#  2   SP      81 non-null     float64
#  3   WT      81 non-null     float64
#  4   MPG     81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
# check for missing values
cars.isna().sum()
# Out:
# HP     0
# VOL    0
# SP     0
# WT     0
# MPG    0
# dtype: int64

# %% [markdown]
# ### Observations
# * No missing values are observed here
# * There are 81 observations
# * The data types provided are relevant with respect to the units

# %%
# Create a figure with two subplots (one above the other)
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios":(.15, .85)})

sns.boxplot(data=cars, x='HP', ax=ax_box, orient='h')
ax_box.set(xlabel=' ')

sns.histplot(data=cars, x='HP', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios":(.15, .85)})

sns.boxplot(data=cars, x='VOL', ax=ax_box, orient='h')
ax_box.set(xlabel=' ')

sns.histplot(data=cars, x='VOL', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios":(.15, .85)})

sns.boxplot(data=cars, x='SP', ax=ax_box, orient='h')
ax_box.set(xlabel=' ')

sns.histplot(data=cars, x='SP', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios":(.15, .85)})

sns.boxplot(data=cars, x='MPG', ax=ax_box, orient='h')
ax_box.set(xlabel=' ')

sns.histplot(data=cars, x='MPG', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios":(.15, .85)})

sns.boxplot(data=cars, x='WT', ax=ax_box, orient='h')
ax_box.set(xlabel=' ')

sns.histplot(data=cars, x='WT', ax=ax_hist, bins=30, kde=True, stat="density")
ax_hist.set(ylabel='Density')

plt.tight_layout()
plt.show()
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Observations
# * There are some extreme values (outliers) observed in towards the right tail of SP and HP distributions
# * In VOL and WT columns, a few outliers are observed in both tails of their distributions
# * The extreme values of cars data may have come from the specially designed nature of the cars
# * As this is multi-dimensional data, the outliers with respect to spatial dimensions may have to be considered while building the regression model

# %%
cars[cars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [HP, VOL, SP, WT, MPG]
# Index: []

# %% [markdown]
# ## Pair plots and correlation coefficients

# %%
sns.set_style(style='darkgrid')
sns.pairplot(cars)
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## Observations
# * The highest positive is HP and SP (0.973848)
# * The high correlations are between WT and VOL
# * The next high correlation is HP and VOL (0.007459)
# * The strong positive corelation is between WT and VOL (0.999203)
# * The low corelation between WT and SP (0.1024)
# * If X columns are having high correlation then it is not desirable as it leads to multicollinearity problem

# %%
cars.corr()
# Out:
#            HP       VOL        SP        WT       MPG
# HP   1.000000  0.077459  0.973848  0.076513 -0.725038
# VOL  0.077459  1.000000  0.102170  0.999203 -0.529057
# SP   0.973848  0.102170  1.000000  0.102439 -0.687125
# WT   0.076513  0.999203  0.102439  1.000000 -0.526759
# MPG -0.725038 -0.529057 -0.687125 -0.526759  1.000000

# %% [markdown]
# ## Preparing a preliminary model considering all X columns

# %%
#Build kodel
model1 = smf.ols('MPG~WT+VOL+SP+HP', data=cars).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     63.80
# Date:                Sat, 08 Feb 2025   Prob (F-statistic):           1.54e-23
# Time:                        10:48:32   Log-Likelihood:                -233.96
# No. Observations:                  81   AIC:                             477.9
# Df Residuals:                      76   BIC:                             489.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6773     14.900      2.059      0.043       1.001      60.354
# ...

# %% [markdown]
# ## Observations from model summary
# * The R-squared and adjusted R-squared values are good and about 75% of variability in Y is explained by X columns
# * The probability values with respect to F-Statistic is close to zero, indicating that all or some of X columns are significant
# * The p-values for VOL and WT are higher than 5% indicating some interaction issue among themselves, which need to be further explored
# * x should be strongly correlated with y but x shouldn't be strongly correlated to another x
# * It is not significant and un dessirable

# %% [markdown]
# ## Performance metrics for model1

# %%
# Find the performance metrics
# Create a data frame with actual y and predicted y columns

df1 = pd.DataFrame()
df1["actual_y1"] = cars["MPG"]
df1.head()
# Out:
#    actual_y1
# 0  53.700681
# 1  50.013401
# 2  50.013401
# 3  45.696322
# 4  50.504232

# %%
# Predict for the given X data columns

pred_y1 = model1.predict(cars.iloc[:,0:4])
df1["pred_y1"] = pred_y1
df1.head()
# Out:
#    actual_y1    pred_y1
# 0  53.700681  43.441935
# 1  50.013401  42.388793
# 2  50.013401  42.279341
# 3  45.696322  42.538360
# 4  50.504232  42.172648

# %%
# Compute the Mean squared error (MSE) for model1

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df1["actual_y1"], df1["pred_y1"])
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
# Out:
# MSE:  18.897141152343096
# RMSE:  4.347084212704315

# %% [markdown]
# ## Checking for multicollinearity among X-columns using VIF method

# %%
cars.head()
# Out:
#    HP  VOL          SP         WT        MPG
# 0  49   89  104.185353  28.762059  53.700681
# 1  55   92  105.461264  30.466833  50.013401
# 2  55   92  105.461264  30.193597  50.013401
# 3  70   92  113.461264  30.632114  45.696322
# 4  53   92  104.461264  29.889149  50.504232

# %%
# Compute VIF values (Variance Inflation Factor)
rsq_hp = smf.ols('HP~WT+VOL+SP',data=cars).fit().rsquared
vif_hp = 1/(1-rsq_hp)

rsq_wt = smf.ols('WT~HP+VOL+SP',data=cars).fit().rsquared  
vif_wt = 1/(1-rsq_wt) 

rsq_vol = smf.ols('VOL~WT+SP+HP',data=cars).fit().rsquared  
vif_vol = 1/(1-rsq_vol) 

rsq_sp = smf.ols('SP~WT+VOL+HP',data=cars).fit().rsquared  
vif_sp = 1/(1-rsq_sp) 

# Storing vif values in a data frame
d1 = {'Variables':['Hp','WT','VOL','SP'],'VIF':[vif_hp,vif_wt,vif_vol,vif_sp]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
#   Variables         VIF
# 0        Hp   19.926589
# 1        WT  639.533818
# 2       VOL  638.806084
# 3        SP   20.007639

# %% [markdown]
# ### Observations
# * The ideal range of VIF values shall be between 0 to 10. However slightly higher values can be tolerated
# * As seen from the very high VIF values for VOL and WT, it is clear that they are prone to multicollinearity problem
# * Hence it is decided to drop one of the columns (either VOL or WT) to overcome the multicollinearity.
# * It is decided to Drop WT and retain VOL column in further models

# %%
cars1 = cars.drop("WT", axis=1)
cars1.head()
# Out:
#    HP  VOL          SP        MPG
# 0  49   89  104.185353  53.700681
# 1  55   92  105.461264  50.013401
# 2  55   92  105.461264  50.013401
# 3  70   92  113.461264  45.696322
# 4  53   92  104.461264  50.504232

# %%
# Build model2 on cars1 dataset
import statsmodels.formula.api as smf
model2 = smf.ols('MPG~VOL+SP+HP',data=cars1).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     86.11
# Date:                Sat, 08 Feb 2025   Prob (F-statistic):           1.56e-24
# Time:                        10:48:34   Log-Likelihood:                -233.99
# No. Observations:                  81   AIC:                             476.0
# Df Residuals:                      77   BIC:                             485.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.9234     14.466      2.069      0.042       1.118      58.729
# ...

# %% [markdown]
# ### Observations
# * R-squared values slightly improved to 0.76%
# * All the P-values for model parameters are < 0.05 so all are highly significant
# * Therefore the HP, VOL, SP columns are finalized as the significant predictor for the MPG
# * There is no improvement in MSE value

# %% [markdown]
# ## Performance metrics for model 2

# %%
# Find the performance metrics for model2
# Create a data frame with actual y and predicted y columns

df2 = pd.DataFrame()
df2["actual_y2"] = cars["MPG"]
df2.head()
# Out:
#    actual_y2
# 0  53.700681
# 1  50.013401
# 2  50.013401
# 3  45.696322
# 4  50.504232

# %%
# Predict for the given X data columns

pred_y2 = model2.predict(cars1.iloc[:,0:4])
df2["pred_y2"] = pred_y2
df2.head()
# Out:
#    actual_y2    pred_y2
# 0  53.700681  43.590769
# 1  50.013401  42.256794
# 2  50.013401  42.256794
# 3  45.696322  42.361497
# 4  50.504232  42.269544

# %%
# Compute the Mean squared error (MSE) for model2

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df2["actual_y2"], df2["pred_y2"])
print("MSE: ", mse)
print("RMSE: ", np.sqrt(mse))
# Out:
# MSE:  18.911053388711228
# RMSE:  4.34868409851891

# %% [markdown]
# ### Identification of High Influence points (spatial outliers)

# %%
cars1.shape
# Out:
# (81, 4)

# %%
#Define variables and assign values
k = 3     # no of x-columns
n= 81     # no. of observations (rows)
leverage_cutoff = 3*((k+1)/n)
leverage_cutoff
# Out:
# 0.14814814814814814

# %%
from statsmodels.graphics.regressionplots import influence_plot

influence_plot(model1,alpha=.05)

y = [i for i in range(-2,8)]
x = [leverage_cutoff for i in range(10)]
plt.plot(x,y, 'r+')

plt.show()

# %% [markdown]
# ### Observations
# * From the above plot, it is evident that data points 65,69, 70, 76, 78, 79,80 are the influencers.
# * As their H leverage values are higher and size is higher

# %%
cars1[cars1.index.isin([65,69,70,76,78,79,80])]
# Out:
#      HP  VOL          SP        MPG
# 65  165   50  126.598513  40.050000
# 69  245  112  158.300669  21.273708
# 70  280   50  164.598513  19.678507
# 76  322   50  169.598513  36.900000
# 78  263   50  151.598513  34.000000
# 79  295  119  167.944460  19.833733
# 80  236  107  139.840817  12.101263

# %%
cars2=cars1.drop(cars.index[[65,70,76,78,79,80]],axis=0).reset_index(drop=True)

# %%
cars2
# Out:
#      HP  VOL          SP        MPG
# 0    49   89  104.185353  53.700681
# 1    55   92  105.461264  50.013401
# 2    55   92  105.461264  50.013401
# 3    70   92  113.461264  45.696322
# 4    53   92  104.461264  50.504232
# ..  ...  ...         ...        ...
# 70  162  132  133.140074  23.203569
# 71  140  160  124.715241  19.086341
# 72  140  129  121.864163  19.086341
# 73  175  129  132.864163  18.762837
# 74  238  115  150.576579  19.197888
#
# [75 rows x 4 columns]

# %%
#Rebuild the model 
model3 = smf.ols('MPG~VOL+SP+HP',data = cars2).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     182.7
# Date:                Sat, 08 Feb 2025   Prob (F-statistic):           2.60e-33
# Time:                        10:48:35   Log-Likelihood:                -187.46
# No. Observations:                  75   AIC:                             382.9
# Df Residuals:                      71   BIC:                             392.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.6816     11.600      0.404      0.688     -18.448      27.811
# ...

# %%
df3 = pd.DataFrame()
df3['actual_y3'] = cars2['MPG']
df3.head()
# Out:
#    actual_y3
# 0  53.700681
# 1  50.013401
# 2  50.013401
# 3  45.696322
# 4  50.504232

# %%
pred_y3 = model3.predict(cars2.iloc[:,0:3])
df3['pred_y3'] = pred_y3
df3.head()
# Out:
#    actual_y3    pred_y3
# 0  53.700681  45.872002
# 1  50.013401  44.385430
# 2  50.013401  44.385430
# 3  45.696322  44.433742
# 4  50.504232  44.421272

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df3["actual_y3"],df3["pred_y3"])
print("MSE :", mse )
print("RMSE :" , np.sqrt(mse))
# Out:
# MSE : 8.681197361563033
# RMSE : 2.9463871710220015

# %% [markdown]
# #### Comparisions of models
# #### _______________________________________________________________
# | Metrics              |Model 1      |Model 2            | Model 3   |
# |----------------------|-------------|-------------------|-----------|
# | R-Squared            | 0.771       | 0.761             | 0.885     |
# | Adj. R-Squared       | 0.758       | 0.761             | 0.880     |
# | MSE                  | 18.89       | 18.91             | 8.68      |
# | RMSE                 | 4.34        | 4.34              | 2.94      |
# #### _______________________________________________________________
# - **From The above comparison table it is observed that model3 is best among all 3 model sets

# %% [markdown]
# #### Check the validity of model assumptions for model3

# %%
model3.resid
# Out:
# 0     7.828680
# 1     5.627971
# 2     5.627971
# 3     1.262580
# 4     6.082960
#         ...
# 70    0.919969
# 71   -2.559623
# 72   -3.702073
# 73    0.724230
# 74    9.700384
# Length: 75, dtype: float64

# %%
model3.fittedvalues
# Out:
# 0     45.872002
# 1     44.385430
# 2     44.385430
# 3     44.433742
# 4     44.421272
#         ...
# 70    22.283600
# 71    21.645963
# 72    22.788414
# 73    18.038607
# 74     9.497504
# Length: 75, dtype: float64

# %%
# The model is built with VOL, SP, HP, by ignoring WT
import statsmodels.api as sm
qqplot = sm.qqplot(model3.resid,line = 'q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
sns.displot(model3.resid,kde = True)
# Out:
# C:\Anaconda Navigator\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
def get_standardized_values(vals):
    return(vals-vals.mean())/vals.std()

# %%
plt.figure(figsize=(6,4))
plt.scatter(get_standardized_values(model3.fittedvalues),
            get_standardized_values(model3.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# #### Final comments :
# - The residuals are approximately
